# %% [markdown]
# Install packages

# %%
import pandas as pd
import numpy as np
import pyodbc
from dotenv import dotenv_values
import warnings

warnings.filterwarnings('ignore')

# %%
# Database connection parameters
server_name = 'dap-projects-database.database.windows.net'
database_name = 'dapDB'
username = 'LP1_learner'
password = 'Hyp0th3s!$T3$t!ng'

connection_string = f'DRIVER=ODBC Driver 17 for SQL Server;SERVER={server_name};DATABASE={database_name};UID={username};PWD={password}'



data1 = 'startup_funding2018.csv'
data2 = 'startup_funding2019.csv'
data3 = 'startup_funding2020.csv'
data4 = 'startup_funding2021.csv'



df1 = pd.read_csv(data1)
df2 = pd.read_csv(data2)
df3 = pd.read_csv(data3)
df4 = pd.read_csv(data4)

# %%
connection = pyodbc.connect(connection_string)

query = "Select * from dbo.LP2_Telco_churn_first_3000"
data = pd.read_sql(query, connection)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The SELECT permission was denied on the object 'LP2_Telco_churn_first_3000', database 'dapDB', schema 'dbo'. (229) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 4
#       1 connection = pyodbc.connect(connection_string)
#       3 query = "Select * from dbo.LP2_Telco_churn_first_3000"
# ----> 4 data = pd.read_sql(query, connection)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/sql.py:2736, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2725 def read_query(
#    2726     self,
#    2727     sql,
#    (...)
#    2734     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2735 ) -> DataFrame | Iterator[DataFrame]:
# -> 2736     cursor = self.execute(sql, params)
#    2737     columns = [col_desc[0] for col_desc in cursor.description]
#    2739     if chunksize is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/sql.py:2684, in SQLiteDatabase.execute(self, sql, params)
#    2681     raise ex from inner_exc
#    2683 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2684 raise ex from exc
#
# DatabaseError: Execution failed on sql 'Select * from dbo.LP2_Telco_churn_first_3000': ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The SELECT permission was denied on the object 'LP2_Telco_churn_first_3000', database 'dapDB', schema 'dbo'. (229) (SQLExecDirectW)")
